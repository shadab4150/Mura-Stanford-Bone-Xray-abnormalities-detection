# %% [markdown]
# <a href="https://colab.research.google.com/github/shadab4150/Mura-Stanford-Bone-Xray-abnormalities-detection/blob/master/mura_stanford_bone_abnormalities_kappa.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install torchviz

# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
from fastai.vision import * 
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from tqdm import tnrange,tqdm
import gc
from graphviz import Digraph
import torch
from torch.autograd import Variable
from torchviz import make_dot

# %%
path = Path('/content/');path.ls()
# Out:
# [PosixPath('/content/.config'),
#  PosixPath('/content/mura_xray'),
#  PosixPath('/content/MURA-v1.1'),
#  PosixPath('/content/final_mura_tr_vl.csv'),
#  PosixPath('/content/mura_final_process.csv'),
#  PosixPath('/content/drive'),
#  PosixPath('/content/models'),
#  PosixPath('/content/.ipynb_checkpoints'),
#  PosixPath('/content/sample_data')]

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
# !unzip '/content/drive/My Drive/Dataset/MURA-v1.1.zip' -d '/content/'

# %% [markdown]
# # Preprocessing training set

# %%
tp = pd.read_csv('/content/MURA-v1.1/train_image_paths.csv',sep='/',header=None)
tl = pd.read_csv('/content/MURA-v1.1/train_labeled_studies.csv',sep='/',header=None)

# %% [markdown]
# ## This dataframe contains paths of training images

# %%
tp.head(3)
# Out:
#            0      1            2             3                4           5
# 0  MURA-v1.1  train  XR_SHOULDER  patient00001  study1_positive  image1.png
# 1  MURA-v1.1  train  XR_SHOULDER  patient00001  study1_positive  image2.png
# 2  MURA-v1.1  train  XR_SHOULDER  patient00001  study1_positive  image3.png

# %% [markdown]
# ## This dataframe contains label of training images

# %%
tl.head(3)
# Out:
#            0      1            2             3                4   5
# 0  MURA-v1.1  train  XR_SHOULDER  patient00001  study1_positive  ,1
# 1  MURA-v1.1  train  XR_SHOULDER  patient00002  study1_positive  ,1
# 2  MURA-v1.1  train  XR_SHOULDER  patient00003  study1_positive  ,1

# %% [markdown]
# ## creating a single path columns from all columns

# %%
paths = []
for i in tnrange(tp.shape[0],desc='row'):
    p = "/".join(str(x) for x in tp.iloc[i].values)
    paths.append(p)
# Out:
# HBox(children=(IntProgress(value=0, description='row', max=36808, style=ProgressStyle(description_width='initi…

# %%
tp['path'] = paths

# %%
tp.columns = ['folder','set','body_part','patient_id','study_PN','image_id','path']
tl.columns = ['folder','set','body_part','patient_id','study_PN','target']

# %%
tp.head(2)
# Out:
#       folder  ...                                               path
# 0  MURA-v1.1  ...  MURA-v1.1/train/XR_SHOULDER/patient00001/study...
# 1  MURA-v1.1  ...  MURA-v1.1/train/XR_SHOULDER/patient00001/study...
#
# [2 rows x 7 columns]

# %%
tl.head(2)
# Out:
#       folder    set    body_part    patient_id         study_PN target
# 0  MURA-v1.1  train  XR_SHOULDER  patient00001  study1_positive     ,1
# 1  MURA-v1.1  train  XR_SHOULDER  patient00002  study1_positive     ,1

# %%
def label(x):
    if x==',1':
        return 1
    elif x==',0':
        return 0

# %%
tl['target']=tl['target'].apply(label,convert_dtype=True)

# %% [markdown]
# * Merging both **path** and **target**

# %%
total = pd.merge(tp,tl,left_on=['folder','set','body_part','patient_id','study_PN'],right_on=['folder','set','body_part','patient_id','study_PN'],how='left')

# %%
total.head()
# Out:
#       folder    set  ...                                               path target
# 0  MURA-v1.1  train  ...  MURA-v1.1/train/XR_SHOULDER/patient00001/study...      1
# 1  MURA-v1.1  train  ...  MURA-v1.1/train/XR_SHOULDER/patient00001/study...      1
# 2  MURA-v1.1  train  ...  MURA-v1.1/train/XR_SHOULDER/patient00001/study...      1
# 3  MURA-v1.1  train  ...  MURA-v1.1/train/XR_SHOULDER/patient00002/study...      1
# 4  MURA-v1.1  train  ...  MURA-v1.1/train/XR_SHOULDER/patient00002/study...      1
#
# [5 rows x 8 columns]

# %% [markdown]
# ## Creating one hot encoded for each body part

# %%
total_new = pd.get_dummies(total,columns=['body_part']);total_new.head()
# Out:
#       folder    set  ... body_part_XR_SHOULDER body_part_XR_WRIST
# 0  MURA-v1.1  train  ...                     1                  0
# 1  MURA-v1.1  train  ...                     1                  0
# 2  MURA-v1.1  train  ...                     1                  0
# 3  MURA-v1.1  train  ...                     1                  0
# 4  MURA-v1.1  train  ...                     1                  0
#
# [5 rows x 14 columns]

# %% [markdown]
# # Preprocessing validation set

# %%
vp = pd.read_csv('/content/MURA-v1.1/valid_image_paths.csv',sep='/',header=None)  ## This dataframe contains paths of validation images
vl = pd.read_csv('/content/MURA-v1.1/valid_labeled_studies.csv',sep='/',header=None) ## This dataframe contains label of validation images

# %% [markdown]
# * Creating a single path columns from all columns

# %%
pathsv = []   
for i in tnrange(vp.shape[0],desc='row'):
    p = "/".join(str(x) for x in vp.iloc[i].values)
    pathsv.append(p)
# Out:
# HBox(children=(IntProgress(value=0, description='row', max=3197, style=ProgressStyle(description_width='initia…

# %%
vp['path'] = pathsv

# %%
vp.columns = ['folder','set','body_part','patient_id','study_PN','image_id','path']
vl.columns = ['folder','set','body_part','patient_id','study_PN','target']

# %%
vl['target']=vl['target'].apply(label,convert_dtype=True)

# %% [markdown]
# * Merging both **path** and **target**

# %%
totalv = pd.merge(vp,vl,left_on=['folder','set','body_part','patient_id','study_PN'],right_on=['folder','set','body_part','patient_id','study_PN'],how='left')

# %%
totalv.head()
# Out:
#       folder    set  ...                                               path target
# 0  MURA-v1.1  valid  ...  MURA-v1.1/valid/XR_WRIST/patient11185/study1_p...      1
# 1  MURA-v1.1  valid  ...  MURA-v1.1/valid/XR_WRIST/patient11185/study1_p...      1
# 2  MURA-v1.1  valid  ...  MURA-v1.1/valid/XR_WRIST/patient11185/study1_p...      1
# 3  MURA-v1.1  valid  ...  MURA-v1.1/valid/XR_WRIST/patient11185/study1_p...      1
# 4  MURA-v1.1  valid  ...  MURA-v1.1/valid/XR_WRIST/patient11186/study1_p...      1
#
# [5 rows x 8 columns]

# %% [markdown]
# ## Creating one hot encoded for each body part

# %%
totalv_new = pd.get_dummies(totalv,columns=['body_part']);totalv_new.head()
# Out:
#       folder    set  ... body_part_XR_SHOULDER body_part_XR_WRIST
# 0  MURA-v1.1  valid  ...                     0                  1
# 1  MURA-v1.1  valid  ...                     0                  1
# 2  MURA-v1.1  valid  ...                     0                  1
# 3  MURA-v1.1  valid  ...                     0                  1
# 4  MURA-v1.1  valid  ...                     0                  1
#
# [5 rows x 14 columns]

# %% [markdown]
# # Final combining both Training and Validation into single dataframe

# %%
final12 = pd.concat([total,totalv]);

# %%
final12.to_csv('mura_final_combined.csv',index=False)

# %%
final12.head()
# Out:
#       folder  ...  target
# 0  MURA-v1.1  ...       1
# 1  MURA-v1.1  ...       1
# 2  MURA-v1.1  ...       1
# 3  MURA-v1.1  ...       1
# 4  MURA-v1.1  ...       1
#
# [5 rows x 8 columns]

# %%
mura = final12[['is_valid','body_part','path','target']].copy()

# %%
for bodypart in mura.body_part.unique():
  print(bodypart+" : "+str(mura[mura['body_part']==bodypart].shape[0]))
# Out:
# XR_SHOULDER : 8942
# XR_HUMERUS : 1560
# XR_FINGER : 5567
# XR_ELBOW : 5396
# XR_WRIST : 10411
# XR_FOREARM : 2126
# XR_HAND : 6003

# %%
mura.to_csv('mura_final_4col.csv',index=False)

# %%
# !cp '/content/mura_final_combined.csv' '/content/drive/My Drive/Dataset/'
# !cp '/content/mura_final_4col.csv' '/content/drive/My Drive/Dataset/'

# %%
final = pd.concat([total_new,totalv_new]);final.head()
# Out:
#       folder    set  ... body_part_XR_SHOULDER body_part_XR_WRIST
# 0  MURA-v1.1  train  ...                     1                  0
# 1  MURA-v1.1  train  ...                     1                  0
# 2  MURA-v1.1  train  ...                     1                  0
# 3  MURA-v1.1  train  ...                     1                  0
# 4  MURA-v1.1  train  ...                     1                  0
#
# [5 rows x 14 columns]

# %%
final.to_csv('final_mura_tr_vl.csv',index=False)

# %%
df = pd.read_csv('/content/drive/My Drive/Dataset/mura_final_onehot.csv');df.sample(n=5)
# Out:
#           folder  is_valid  ... body_part_XR_SHOULDER body_part_XR_WRIST
# 238    MURA-v1.1     False  ...                     1                  0
# 13638  MURA-v1.1     False  ...                     0                  0
# 4344   MURA-v1.1     False  ...                     1                  0
# 6450   MURA-v1.1     False  ...                     1                  0
# 21381  MURA-v1.1     False  ...                     0                  1
#
# [5 rows x 14 columns]

# %%
train = pd.read_csv('/content/drive/My Drive/Dataset/mura_final_4col.csv')
train.sample(n=10)
# Out:
#        is_valid  ... target
# 37514      True  ...      1
# 12073     False  ...      0
# 23274     False  ...      1
# 39480      True  ...      0
# 18785     False  ...      0
# 32830     False  ...      0
# 36039     False  ...      0
# 31386     False  ...      1
# 14490     False  ...      0
# 32485     False  ...      1
#
# [10 rows x 4 columns]

# %% [markdown]
# ### Forming a validation set:
# * As described in mura

# %%
def targ(x):
  if x==1:
    return 'abnormal'
  elif x==0:
    return 'normal'

# %%
df.target=df.target.apply(targ,convert_dtype=True)

# %%
df.sample(n=10)
# Out:
#           folder  is_valid  ... body_part_XR_SHOULDER body_part_XR_WRIST
# 17361  MURA-v1.1     False  ...                     0                  0
# 30362  MURA-v1.1     False  ...                     0                  0
# 15767  MURA-v1.1     False  ...                     0                  0
# 3545   MURA-v1.1     False  ...                     1                  0
# 10291  MURA-v1.1     False  ...                     0                  0
# 33603  MURA-v1.1     False  ...                     0                  0
# 2088   MURA-v1.1     False  ...                     1                  0
# 22966  MURA-v1.1     False  ...                     0                  1
# 2927   MURA-v1.1     False  ...                     1                  0
# 23060  MURA-v1.1     False  ...                     0                  1
#
# [10 rows x 14 columns]

# %%
cols_onehot = ['target',
       'body_part_XR_ELBOW', 'body_part_XR_FINGER', 'body_part_XR_FOREARM',
       'body_part_XR_HAND', 'body_part_XR_HUMERUS', 'body_part_XR_SHOULDER',
       'body_part_XR_WRIST']

# %%
img =open_image(path/df.path.iloc[0])
print(img.shape)
print('--'*30)
img.show(figsize=(20,8),title='sample image X-Ray Shoulder')
# Out:
# torch.Size([3, 512, 380])
# ------------------------------------------------------------

# %%
tfms=get_transforms(do_flip=True)

# %%
data = (ImageList.from_df(df,path,cols='path')
                .split_from_df(col='is_valid')
                .label_from_df(cols='target')
                .transform(size=256)
                .databunch(bs=128).normalize(imagenet_stats))

# %%
data.show_batch(rows=4,figsize=(22,10))

# %%
data.classes,len(data.train_ds),len(data.valid_ds)
# Out:
# (['abnormal', 'normal'], 36808, 3197)

# %%
data.train_ds[0][0].shape
# Out:
# torch.Size([3, 256, 256])

# %%
gc.collect()
# Out:
# 2102

# %%
arch = models.resnet18(pretrained=False)

# %%
acc_02 = partial(accuracy_thresh, thresh=0.2)
f_score = partial(fbeta, thresh=0.2)
kp = KappaScore()
kp.weights = 'quadratic'

# %%
learn = cnn_learner(data, models.resnet18 , metrics = [kp] )

# %%
print(learn.summary())
# Out:
# Sequential
# ======================================================================
# Layer (type)         Output Shape         Param #    Trainable
# ======================================================================
# Conv2d               [64, 128, 128]       9,408      False
# ______________________________________________________________________
# BatchNorm2d          [64, 128, 128]       128        True
# ______________________________________________________________________
# ReLU                 [64, 128, 128]       0          False
# ______________________________________________________________________
# MaxPool2d            [64, 64, 64]         0          False
# ______________________________________________________________________
# Conv2d               [64, 64, 64]         36,864     False
# ______________________________________________________________________
# BatchNorm2d          [64, 64, 64]         128        True
# ______________________________________________________________________
# ReLU                 [64, 64, 64]         0          False
# ______________________________________________________________________
# Conv2d               [64, 64, 64]         36,864     False
# ______________________________________________________________________
# BatchNorm2d          [64, 64, 64]         128        True
# ______________________________________________________________________
# Conv2d               [64, 64, 64]         36,864     False
# ______________________________________________________________________
# BatchNorm2d          [64, 64, 64]         128        True
# ______________________________________________________________________
# ReLU                 [64, 64, 64]         0          False
# ______________________________________________________________________
# Conv2d               [64, 64, 64]         36,864     False
# ______________________________________________________________________
# BatchNorm2d          [64, 64, 64]         128        True
# ______________________________________________________________________
# Conv2d               [128, 32, 32]        73,728     False
# ______________________________________________________________________
# BatchNorm2d          [128, 32, 32]        256        True
# ______________________________________________________________________
# ReLU                 [128, 32, 32]        0          False
# ______________________________________________________________________
# Conv2d               [128, 32, 32]        147,456    False
# ______________________________________________________________________
# BatchNorm2d          [128, 32, 32]        256        True
# ______________________________________________________________________
# Conv2d               [128, 32, 32]        8,192      False
# ______________________________________________________________________
# BatchNorm2d          [128, 32, 32]        256        True
# ______________________________________________________________________
# Conv2d               [128, 32, 32]        147,456    False
# ______________________________________________________________________
# BatchNorm2d          [128, 32, 32]        256        True
# ______________________________________________________________________
# ReLU                 [128, 32, 32]        0          False
# ______________________________________________________________________
# Conv2d               [128, 32, 32]        147,456    False
# ______________________________________________________________________
# BatchNorm2d          [128, 32, 32]        256        True
# ______________________________________________________________________
# Conv2d               [256, 16, 16]        294,912    False
# ______________________________________________________________________
# BatchNorm2d          [256, 16, 16]        512        True
# ______________________________________________________________________
# ReLU                 [256, 16, 16]        0          False
# ______________________________________________________________________
# Conv2d               [256, 16, 16]        589,824    False
# ______________________________________________________________________
# BatchNorm2d          [256, 16, 16]        512        True
# ______________________________________________________________________
# Conv2d               [256, 16, 16]        32,768     False
# ______________________________________________________________________
# BatchNorm2d          [256, 16, 16]        512        True
# ______________________________________________________________________
# Conv2d               [256, 16, 16]        589,824    False
# ______________________________________________________________________
# BatchNorm2d          [256, 16, 16]        512        True
# ______________________________________________________________________
# ReLU                 [256, 16, 16]        0          False
# ______________________________________________________________________
# Conv2d               [256, 16, 16]        589,824    False
# ______________________________________________________________________
# BatchNorm2d          [256, 16, 16]        512        True
# ______________________________________________________________________
# Conv2d               [512, 8, 8]          1,179,648  False
# ______________________________________________________________________
# BatchNorm2d          [512, 8, 8]          1,024      True
# ______________________________________________________________________
# ReLU                 [512, 8, 8]          0          False
# ______________________________________________________________________
# Conv2d               [512, 8, 8]          2,359,296  False
# ______________________________________________________________________
# BatchNorm2d          [512, 8, 8]          1,024      True
# ______________________________________________________________________
# Conv2d               [512, 8, 8]          131,072    False
# ______________________________________________________________________
# BatchNorm2d          [512, 8, 8]          1,024      True
# ______________________________________________________________________
# Conv2d               [512, 8, 8]          2,359,296  False
# ______________________________________________________________________
# BatchNorm2d          [512, 8, 8]          1,024      True
# ______________________________________________________________________
# ReLU                 [512, 8, 8]          0          False
# ______________________________________________________________________
# Conv2d               [512, 8, 8]          2,359,296  False
# ______________________________________________________________________
# BatchNorm2d          [512, 8, 8]          1,024      True
# ______________________________________________________________________
# AdaptiveAvgPool2d    [512, 1, 1]          0          False
# ______________________________________________________________________
# AdaptiveMaxPool2d    [512, 1, 1]          0          False
# ______________________________________________________________________
# Flatten              [1024]               0          False
# ______________________________________________________________________
# BatchNorm1d          [1024]               2,048      True
# ______________________________________________________________________
# Dropout              [1024]               0          False
# ______________________________________________________________________
# Linear               [512]                524,800    True
# ______________________________________________________________________
# ReLU                 [512]                0          False
# ______________________________________________________________________
# BatchNorm1d          [512]                1,024      True
# ______________________________________________________________________
# Dropout              [512]                0          False
# ______________________________________________________________________
# Linear               [2]                  1,026      True
# ______________________________________________________________________
#
# Total params: 11,705,410
# Total trainable params: 538,498
# Total non-trainable params: 11,166,912
# Optimized with 'torch.optim.adam.Adam', betas=(0.9, 0.99)
# Using true weight decay as discussed in https://www.fast.ai/2018/07/02/adam-weight-decay/
# Loss function : FlattenedLoss
# ======================================================================
# Callbacks functions applied

# %%
x = Variable(torch.rand(64, 3,256,256))
y = arch(x)

# %% [markdown]
# # Model Parameters and structure

# %%
make_dot(y.mean(),params=dict(arch.named_parameters()))

# %%
gc.collect()
# Out:
# 48468

# %%
learn.lr_find()

# %%
learn.recorder.plot()

# %%
gc.collect()
# Out:
# 0

# %%
np.linspace(1e-2,1e-1,5)
# Out:
# array([0.01  , 0.0325, 0.055 , 0.0775, 0.1   ])

# %% [markdown]
# ## metrics with one_hot encoded targets

# %%
learn.fit_one_cycle(2 , 0.055 , moms=(0.8,0.7) )
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy_thresh</th>
#       <th>fbeta</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.135149</td>
#       <td>0.196755</td>
#       <td>0.895058</td>
#       <td>0.822307</td>
#       <td>05:48</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.091740</td>
#       <td>0.102969</td>
#       <td>0.946082</td>
#       <td>0.905476</td>
#       <td>05:36</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Metrics with kappa score
# * combined all body parts at once

# %%
learn.fit_one_cycle(2 , 0.055 , moms=(0.8,0.7) )
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>kappa_score</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.559112</td>
#       <td>0.566215</td>
#       <td>0.409757</td>
#       <td>05:38</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.485238</td>
#       <td>0.488565</td>
#       <td>0.526004</td>
#       <td>05:28</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.save('model1')

# %%
learn.fit_one_cycle(3 , 1e-2 , moms=(0.8,0.7) )
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>kappa_score</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.485891</td>
#       <td>0.590681</td>
#       <td>0.468553</td>
#       <td>05:23</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.455342</td>
#       <td>0.507002</td>
#       <td>0.518402</td>
#       <td>05:15</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.432739</td>
#       <td>0.465945</td>
#       <td>0.575228</td>
#       <td>05:24</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.export('mura.pkl')

# %%
img = df[df['is_valid']==True].path.iloc[45];img
print(df[df['is_valid']==True].abnormal.iloc[45])
# Out:
# 1

# %% [markdown]
# ## Making Predictions with the model

# %%
image = open_image(img)
print(learn.predict(image)[0])
image
# Out:
# abnormal;body_part_XR_WRIST
# Image (3, 512, 319)
